# %%
from src.Fetch import Fetch
from src.StochasticFeatureEngine import StochasticFeatureEngine

fetcher = Fetch()

df = fetcher.fetch("SPY")
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 6
#       2 from src.StochasticFeatureEngine import StochasticFeatureEngine
#       4 fetcher = Fetch()
# ----> 6 df = fetcher.fetch("SPY")
#       7 df.head()
#
# File ~/Programming/rl-regime-trading/src/Fetch.py:39, in Fetch.fetch(self, symbol)
#      37 def fetch(self, symbol):
#      38     data = self.get_daily(symbol=symbol)
# ---> 39     df = self.json_to_df(data)
#      40     df['Log_Return'] = np.log(
#      41         df['close'] / df['close'].shift(1))
#      42     return df
#
# File ~/Programming/rl-regime-trading/src/Fetch.py:21, in Fetch.json_to_df(self, data)
#      20 def json_to_df(self, data):
# ---> 21     ts = data["Time Series (Daily)"]
#      22     df = pd.DataFrame.from_dict(ts, orient="index")
#      23     df.index = pd.to_datetime(df.index)
#
# KeyError: 'Time Series (Daily)'

# %%
from dotenv import load_dotenv
import requests
import os

load_dotenv()

av_api_key = os.getenv("ALPHA_VANTAGE_API_KEY")

url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=SPY&outputsize=full&apikey={av_api_key}'
r = requests.get(url)
data = r.json()

# %%
# Out:
# {'Information': 'We have detected your API key as YB6AJ9W5IJIII8FX and our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
